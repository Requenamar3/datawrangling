# %% [markdown]
# <a href="https://colab.research.google.com/github/Requenamar3/datawrangling/blob/main/Untitled169.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
cars = pd.read_pickle("https://github.com/fenago/datasets/raw/main/cars.pkl")

# %%
cars.head()
# Out:
#   aspiration      carbody  enginesize  curbweight    price
# 0        std  convertible         130        2548  13495.0
# 1        std  convertible         130        2548  16500.0
# 2        std    hatchback         152        2823  16500.0
# 3        std        sedan         109        2337  13950.0
# 4        std        sedan         136        2824  17450.0

# %%
cars_melted = pd.melt(cars, id_vars='price',
                      value_vars=['enginesize','curbweight'],
                      var_name='feature', value_name='featureValue')
cars_melted
# Out:
#        price     feature  featureValue
# 0    13495.0  enginesize           130
# 1    16500.0  enginesize           130
# 2    16500.0  enginesize           152
# 3    13950.0  enginesize           109
# 4    17450.0  enginesize           136
# ..       ...         ...           ...
# 405  16845.0  curbweight          2952
# 406  19045.0  curbweight          3049
# 407  21485.0  curbweight          3012
# 408  22470.0  curbweight          3217
# 409  22625.0  curbweight          3062
#
# [410 rows x 3 columns]

# %%
sns.relplot(data=cars_melted, x='featureValue', y='price',
            hue='feature')

# %%
sns.relplot(data=cars_melted, x='featureValue', y='price',
            col='feature', facet_kws={'sharex':False})

# %%
fires = pd.read_pickle("https://github.com/fenago/datasets/raw/main/fires_prepared.pkl")

# %%
fires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 274123 entries, 16 to 1880441
# Data columns (total 8 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   fire_name       128667 non-null  object
#  1   fire_year       274123 non-null  int64
#  2   state           274123 non-null  object
#  3   discovery_date  274123 non-null  datetime64[ns]
#  4   contain_date    137376 non-null  datetime64[ns]
#  5   acres_burned    274123 non-null  float64
#  6   fire_month      274123 non-null  int64
#  7   days_burning    137376 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(2), object(2)
# memory usage: 18.8+ MB

# %%
fires.groupby('state').mean().head()
# Out:
# <ipython-input-14-5330d000f74d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   fires.groupby('state').mean().head()
#          fire_year  acres_burned  fire_month  days_burning
# state
# AK     2004.742504  11367.199362    6.264198     32.081535
# AL     2003.885422     42.348169    5.022529      0.272676
# AR     2005.850793     50.281673    5.581081      0.400992
# AZ     2001.158390    947.294247    6.293322      4.887679
# CA     2002.171830    881.934274    7.235541      5.387197

# %%
fires.groupby(['state','fire_year','fire_month']).max().head(3)
# Out:
# <ipython-input-15-bacbbb56f1a1>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   fires.groupby(['state','fire_year','fire_month']).max().head(3)
#                            discovery_date contain_date  acres_burned  \
# state fire_year fire_month
# AK    1992      5              1992-05-31   1992-06-22        1410.0
#                 6              1992-06-29   1992-09-17       48087.0
#                 7              1992-07-30   1992-09-17       35090.0
#
#                             days_burning
# state fire_year fire_month
# AK    1992      5                   50.0
#                 6                   82.0
#                 7                   77.0

# %%
fires.head()
# Out:
#        fire_name  fire_year state discovery_date contain_date  acres_burned  \
# 16         Power       2004    CA     2004-10-06   2004-10-21       16823.0
# 17         Freds       2004    CA     2004-10-13   2004-10-17        7700.0
# 25      Bachelor       2004    NM     2004-07-20   2004-07-20          10.0
# 37    Howard Gap       2005    NC     2005-01-27   2005-01-28          50.3
# 39  Austin Creek       2005    NC     2005-02-12   2005-02-13         125.0
#
#     fire_month  days_burning
# 16          10          15.0
# 17          10           4.0
# 25           7           0.0
# 37           1           1.0
# 39           2           1.0

# %%
yearly_group = fires.groupby('fire_year')
yearly_sums = yearly_group.sum()
yearly_sums.head(3)
# Out:
# <ipython-input-18-bb274e1b9cdd>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   yearly_sums = yearly_group.sum()
#            acres_burned  fire_month  days_burning
# fire_year
# 1992         2123889.91       45643        6230.0
# 1993         2118394.10       52880        7283.0
# 1994         4033880.06       57669       20158.0

# %%
yearly_group = fires.groupby('fire_year', as_index=False)
yearly_sums = yearly_group.sum()
yearly_sums.head(3)
# Out:
# <ipython-input-19-843c358efe10>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   yearly_sums = yearly_group.sum()
#    fire_year  acres_burned  fire_month  days_burning
# 0       1992    2123889.91       45643        6230.0
# 1       1993    2118394.10       52880        7283.0
# 2       1994    4033880.06       57669       20158.0

# %%
monthly_group = fires.groupby(['state','fire_year','fire_month'])
monthly_group

# %%
monthly_group.agg(['sum','count','mean']).head(3)
# Out:
# <ipython-input-23-a758fa18d2f6>:1: FutureWarning: ['fire_name', 'discovery_date', 'contain_date'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   monthly_group.agg(['sum','count','mean']).head(3)
#                            acres_burned                    days_burning        \
#                                     sum count         mean          sum count
# state fire_year fire_month
# AK    1992      5                4202.0    15   280.133333        135.0    14
#                 6               86401.0    26  3323.115385        417.0    25
#                 7               48516.7    26  1866.026923        500.0    22
#
#
#                                  mean
# state fire_year fire_month
# AK    1992      5            9.642857
#                 6           16.680000
#                 7           22.727273

# %%
monthly_group.days_burning.agg(['sum','count','mean']).head(3)
# Out:
#                               sum  count       mean
# state fire_year fire_month
# AK    1992      5           135.0     14   9.642857
#                 6           417.0     25  16.680000
#                 7           500.0     22  22.727273

# %%
df = monthly_group.agg({'acres_burned':['sum','max','min'],
                   'days_burning':['sum','mean'],
                   'fire_name':'count'})
df.head(3)
# Out:
#                            acres_burned                days_burning  \
#                                     sum      max   min          sum
# state fire_year fire_month
# AK    1992      5                4202.0   1410.0  10.0        135.0
#                 6               86401.0  48087.0  10.0        417.0
#                 7               48516.7  35090.0  10.0        500.0
#
#                                       fire_name
#                                  mean     count
# state fire_year fire_month
# AK    1992      5            9.642857        14
#                 6           16.680000        23
#                 7           22.727273        26

# %%
states = ['AK','CA','ID','TX']
top_states = fires.groupby(['state','fire_year'], as_index=False).sum()
top_states = top_states.query('state in @states')
top_states.head(2)
# Out:
# <ipython-input-30-cda345c3d10f>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   top_states = fires.groupby(['state','fire_year'], as_index=False).sum()
#   state  fire_year  acres_burned  fire_month  days_burning
# 0    AK       1992      142444.7         454        1145.0
# 1    AK       1993      686630.5         961        3373.0

# %%
top_states.pivot(index='fire_year', columns='state', values='acres_burned').head(2)
# Out:
# state            AK        CA        ID        TX
# fire_year
# 1992       142444.7  289254.9  683495.2   31500.3
# 1993       686630.5  315011.1    7658.5  114265.5

# %%
top_states.pivot(index='fire_year', columns='state', values='acres_burned').plot()
# Out:
# <Axes: xlabel='fire_year'>

# %%
states = ['AK','CA','ID','TX']
fires_top_4 = fires.query('state in @states')
fires_top_4 = fires_top_4.pivot_table(index='fire_year', columns='state',
                                      values='acres_burned', aggfunc='sum')
fires_top_4.head(2)
# Out:
# state            AK        CA        ID        TX
# fire_year
# 1992       142444.7  289254.9  683495.2   31500.3
# 1993       686630.5  315011.1    7658.5  114265.5

# %%
fires_top_4.plot()
# Out:
# <Axes: xlabel='fire_year'>

# %%
fires = pd.read_pickle("https://github.com/fenago/datasets/raw/main/fires_prepared.pkl")

# %%
# !pip install geopandas

# %%
fires.head()
# Out:
#        fire_name  fire_year state discovery_date contain_date  acres_burned  \
# 16         Power       2004    CA     2004-10-06   2004-10-21       16823.0
# 17         Freds       2004    CA     2004-10-13   2004-10-17        7700.0
# 25      Bachelor       2004    NM     2004-07-20   2004-07-20          10.0
# 37    Howard Gap       2005    NC     2005-01-27   2005-01-28          50.3
# 39  Austin Creek       2005    NC     2005-02-12   2005-02-13         125.0
#
#     fire_month  days_burning
# 16          10          15.0
# 17          10           4.0
# 25           7           0.0
# 37           1           1.0
# 39           2           1.0

# %%
# Handle missing values
fires['fire_name'].fillna('Unknown', inplace=True)
fires['contain_date'].fillna(fires['discovery_date'], inplace=True)
fires['days_burning'].fillna(0, inplace=True)

# Extract month from discovery_date
fires['fire_month'] = fires['discovery_date'].dt.month

# %%
import geopandas as gpd
from shapely.geometry import Point
fires['geometry'] = Point(0,0)
gdf = gpd.GeoDataFrame(fires, geometry='geometry')

# %%
state_burned_area = gdf.groupby('state')['acres_burned'].sum().reset_index()

# %%
gdf.plot()
# Out:
# <Axes: >

# %%
#Write out the versions of all packages to requirements.txt
# !pip freeze >> requirements.txt

# %%
install -r requirements.txt
# Out:
#   File "<ipython-input-53-2f7747e5a8cb>", line 1
#     install -r requirements.txt
#                ^
# SyntaxError: invalid syntax

# %%
# !pip install -r requirements.txt
# Out:
# Collecting en-core-web-sm@ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl#sha256=86cc141f63942d4b2c5fcee06630fd6f904788d2f0ab005cce45aadb8fb73889 (from -r requirements.txt (line 84))
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 39.5 MB/s eta 0:00:00
# Processing /colabtools/dist/google-colab-1.0.0.tar.gz (from -r requirements.txt (line 140))
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/colabtools/dist/google-colab-1.0.0.tar.gz'
