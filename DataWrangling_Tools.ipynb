# %% [markdown]
# <a href="https://colab.research.google.com/github/Requenamar3/datawrangling/blob/main/DataWrangling_Tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ydata_profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport
df = pd.read_csv("https://raw.githubusercontent.com/biancarodriguez009/datasets/main/Data%20Analyst%20Salaries%20in%20The%20USA.csv")
df.head()
# Out:
#                         Title  Min Salary  ...  State Remote
# 0         Carbon data analyst         NaN  ...    NaN     No
# 1                Data Analyst     80783.0  ...    NaN     No
# 2  Data Reporting Analyst III     75300.0  ...    NaN     No
# 3         Senior Data Analyst     78700.0  ...     CA    Yes
# 4        Product Data Analyst     95200.0  ...    NaN    Yes
#
# [5 rows x 7 columns]

# %%
profile = ProfileReport(df, title="Profiling Report")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.6.4&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-01-24 23:46:15.000937&quot;&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# !pip install pandasai

# %%
import pandas as pd
from pandasai import SmartDataframe
import warnings
warnings.filterwarnings('ignore')
# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/fenago/datasets/main/BPD_Arrests.csv')

# %%
df.head()
# Out:
#        Arrest   Age Sex Race  ArrestDate ArrestTime    ArrestLocation  \
# 0  16160529.0  54.0   M    B  11/12/2016      22:35   3500 PELHAM AVE
# 1  16160490.0  22.0   M    B  11/12/2016      21:49  300 S LOUDON AVE
# 2  16160487.0  31.0   M    B  11/12/2016      21:40               NaN
# 3  16160485.0  31.0   M    B  11/12/2016      20:30               NaN
# 4  16160481.0  33.0   M    B  11/12/2016      19:45               NaN
#
#     IncidentOffense  IncidentLocation  Charge          ChargeDescription  \
# 0  4ECOMMON ASSAULT   3500 PELHAM AVE  1 1415             COMMON ASSAULT
# 1   Unknown Offense  300 S LOUDON AVE  4 3550                 POSSESSION
# 2   Unknown Offense               NaN  1 0077          FAILURE TO APPEAR
# 3   Unknown Offense               NaN  1 0077          FAILURE TO APPEAR
# 4   Unknown Offense               NaN  2 0480  MOTOR VEH/UNLAWFUL TAKING
#
#        District   Post   Neighborhood                       Location 1
# ...

# %%
from pandasai.llm import OpenAI
llm = OpenAI(api_token="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")

# %%
sdf = SmartDataframe(df, config={"llm": llm})

# %%
race = sdf[sdf['Race'] == 'B']

# %%
race
# Out:
#             Arrest   Age Sex Race  ArrestDate ArrestTime     ArrestLocation  \
# 0       16160529.0  54.0   M    B  11/12/2016      22:35    3500 PELHAM AVE
# 1       16160490.0  22.0   M    B  11/12/2016      21:49   300 S LOUDON AVE
# 2       16160487.0  31.0   M    B  11/12/2016      21:40                NaN
# 3       16160485.0  31.0   M    B  11/12/2016      20:30                NaN
# 4       16160481.0  33.0   M    B  11/12/2016      19:45                NaN
# ...            ...   ...  ..  ...         ...        ...                ...
# 130707  13610411.0  34.0   M    B  01/01/2013      00:15  5200 BEAUFORT AVE
# 130709  13610390.0  33.0   M    B  01/01/2013      00:10                NaN
# 130710  13610403.0  37.0   M    B  01/01/2013      00:05   2700 E BIDDLE ST
# 130711  13610402.0  46.0   M    B  01/01/2013      00:05   2700 E BIDDLE ST
# 130712  13610398.0  40.0   M    B  01/01/2013      00:05   3900 BATEMAN AVE
#
#          IncidentOffense  IncidentLocation  Charge  \
# ...

# %%
sdf.chat("Show me the data types")
# Out:
# WARNING:pandasai.helpers.logger:Failed to execute code with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/smart_datalake_chat/code_execution.py", line 53, in execute
#     result = pipeline_context.query_exec_tracker.execute_func(
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/helpers/query_exec_tracker.py", line 134, in execute_func
#     step_data = self._generate_exec_step(tag, result)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/helpers/query_exec_tracker.py", line 183, in _generate_exec_step
#     self._response = self._format_response(result)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/helpers/query_exec_tracker.py", line 198, in _format_response
#     df_dict = self.convert_dataframe_to_dict(result["value"])
# ...

# %%
sdf.chat("Show me the missing values in the dataset")
# Out:
# WARNING:pandasai.helpers.logger:Failed to execute code with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/smart_datalake_chat/code_execution.py", line 53, in execute
#     result = pipeline_context.query_exec_tracker.execute_func(
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/helpers/query_exec_tracker.py", line 134, in execute_func
#     step_data = self._generate_exec_step(tag, result)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/helpers/query_exec_tracker.py", line 183, in _generate_exec_step
#     self._response = self._format_response(result)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/helpers/query_exec_tracker.py", line 198, in _format_response
#     df_dict = self.convert_dataframe_to_dict(result["value"])
# ...

# %%
print(sdf.last_code_generated)
# Out:
# missing_values = dfs[0].isnull().sum()
# missing_values_df = pd.DataFrame(missing_values, columns=['Missing Values'])
# result = {'type': 'dataframe', 'value': missing_values_df}
# result

# %%
sdf.chat("Which charge descriptions are most common?")
# Out:
# WARNING:pandasai.helpers.logger:Failed to execute code with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/smart_datalake_chat/code_execution.py", line 53, in execute
#     result = pipeline_context.query_exec_tracker.execute_func(
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/helpers/query_exec_tracker.py", line 134, in execute_func
#     step_data = self._generate_exec_step(tag, result)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/helpers/query_exec_tracker.py", line 183, in _generate_exec_step
#     self._response = self._format_response(result)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/helpers/query_exec_tracker.py", line 198, in _format_response
#     df_dict = self.convert_dataframe_to_dict(result["value"])
# ...

# %%
sdf.chat("Show me the demographic breakdown of arrestees")
# Out:
#   Race   Count
# 0    B  106652
# 1    W   20683
# 2    U    2660
# 3    I     375
# 4    A     343

# %%
sdf.chat("Plot a chart of the arrests by Race")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
sdf.plot_pie_chart(labels="district", values="arrest_count")
